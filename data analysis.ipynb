# %% [markdown]
# Dataset on Amazon's Top 50 bestselling books from 2009 to 2019. Contains 550 books, data has been categorized into fiction and non-fiction using Goodreads

# %%
import pandas as pd

# %%
df= pd.read_csv("C:/Users/Admin/Desktop/daily practise/19 may/archive/bestsellers with categories.csv")

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Q the number of fictional and non fictional books sold each year?

# %%
df.shape
# Out:
# (550, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
x=df['Year'].unique()
x
# Out:
# array([2016, 2011, 2018, 2017, 2019, 2014, 2010, 2009, 2015, 2013, 2012],
#       dtype=int64)

# %%
y=df['Genre'].unique()
y
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %%
countf=[]
countfc=[]
for i in range(len(x)):
    f=0
    fc=0
    for k in range(len(df['Year'])):
        #print(df["Year"][k],df["Genre"][k],x[0],y[0])
        if df["Year"][k]==x[i] and df["Genre"][k]==y[0]:
            f+=1
        if df["Year"][k]==x[i] and df["Genre"][k]==y[1]:
            fc+=1
    countf.append(f)
    countfc.append(fc)

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x,countf)
plt.xlabel("Years")
plt.ylabel("Number of non-fictional book")
plt.title("Years versus the number of non-fictional books in top 50")
plt.show()

# %%
plt.bar(x,countfc)
plt.xlabel("Years")
plt.ylabel("Number of fictional book")
plt.title("Years versus the number of fictional books in top 50")
plt.show()

# %%
import seaborn as sns

# %%
ax=sns.barplot(x=x, y=countf)
ax.set_title("Years versus the number of non-fictional books in top 50")
ax.set(xlabel="Years", ylabel= "Number of non-fictional book")
# Out:
# [Text(0, 0.5, 'Number of non-fictional book'), Text(0.5, 0, 'Years')]

# %%
bx=sns.barplot(x=x, y=countfc)
bx.set_title("Years versus the number of fictional books in top 50")
bx.set(xlabel="Years", ylabel= "Number of fictional book")
# Out:
# [Text(0, 0.5, 'Number of fictional book'), Text(0.5, 0, 'Years')]

# %%
cx=sns.lineplot(x=x, y=countf)
cx=sns.lineplot(x=x, y=countfc)
cx.set_title("Years versus the number of books in top 50")
cx.set(xlabel="Years", ylabel= "Number of book")
cx.legend(y)

# %%
# conclusion

# we can observe that in year 2014 there was huge ineterst for "fictional" bokks over "non fictional"
# in the 2015 the trend has chaged drastically
# for other years we can see that readers pefer "non fictional" books slightly more than "fictional" books

# %%
# analysis more about the number of fictional and non fictional books per year

# %%
import numpy as np

# %%
mean_nonfictional= np.mean(np.array(countf))
print(mean_nonfictional)
# Out:
# 28.181818181818183

# %%
mean_fictional= np.mean(np.array(countfc))
print(mean_fictional)
# Out:
# 21.818181818181817

# %%
# People are more inclined towards non fictional books

# %%
print(countfc,countf)
# Out:
# [19, 21, 21, 24, 20, 29, 20, 24, 17, 24, 21] [31, 29, 29, 26, 30, 21, 30, 26, 33, 26, 29]

# %%
plt.scatter(countfc,countf)
plt.xlabel("fictional book per year")
plt.ylabel("nonfictional book per year")
plt.show()

# %%
dict_={"Non-fictional":countf , "Fictional":countfc}
df1=pd.DataFrame(data=dict_)

# %%
#plotting CDF of Fictional and Non fictional books

# %%
countsfc, bin_edgesfc = np.histogram(df1['Non-fictional'],bins=5, density = True)
pdffc = countsfc/(sum(countsfc))
cdffc = np.cumsum(pdffc)
countsf, bin_edgesf = np.histogram(df1['Fictional'],bins=5, density = True)
pdff = countsf/(sum(countsf))
cdff = np.cumsum(pdff)
plt.plot(bin_edges[1:],pdffc)
plt.plot(bin_edges[1:], cdffc)
plt.plot(bin_edges[1:],pdff)
plt.plot(bin_edges[1:], cdff)

# %%
# since we dont have too much data the PDF and CDF are not smooth

# %%
# Ananlysing user review,price and user ratings

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df2=df[["User Rating","Reviews","Price","Genre"]]

sns.pairplot(df2, hue="Genre")
plt.show()

# %%
# most of the popular books are price below $25
# number of the reviews of popular books are about 30000 (will see it in more detail below)
# most of user ratings for popular books are above 4.5

# %%
sns.FacetGrid(df2, hue="Genre", height=5) \
   .map(sns.distplot, "User Rating") \
   .add_legend()
plt.show()

# %%
print(np.mean(np.array(df2["User Rating"][df["Genre"]=="Fiction"])))
print(np.median(np.array(df2["User Rating"][df["Genre"]=="Fiction"])))
print(np.std(np.array(df2["User Rating"][df["Genre"]=="Fiction"])))
# Out:
# 4.6483333333333325
# 4.7
# 0.2645698815478101

# %%
print(np.mean(np.array(df2["User Rating"][df["Genre"]=="Non Fiction"])))
print(np.median(np.array(df2["User Rating"][df["Genre"]=="Non Fiction"])))
print(np.std(np.array(df2["User Rating"][df["Genre"]=="Non Fiction"])))
# Out:
# 4.59516129032258
# 4.6
# 0.1892492973991634

# %%
# Average,median of user rating of both fictional and non fictional are almost same
# Std deviation of fictional books is more than non fictional books

# %%
sns.boxplot(x="Genre", y="User Rating", data=df2)
plt.show()

# %%
sns.FacetGrid(df2, hue="Genre", height=5) \
   .map(sns.distplot, "Reviews") \
   .add_legend()
plt.show()

# %%
print(np.mean(np.array(df2["Reviews"][df["Genre"]=="Fiction"])))
print(np.median(np.array(df2["Reviews"][df["Genre"]=="Fiction"])))
print(np.std(np.array(df2["Reviews"][df["Genre"]=="Fiction"])))
# Out:
# 15683.791666666666
# 10922.0
# 13954.956893457747

# %%
print(np.mean(np.array(df2["Reviews"][df["Genre"]=="Non Fiction"])))
print(np.median(np.array(df2["Reviews"][df["Genre"]=="Non Fiction"])))
print(np.std(np.array(df2["Reviews"][df["Genre"]=="Non Fiction"])))
# Out:
# 9065.145161290322
# 6346.0
# 8592.844581106843

# %%
sns.boxplot(x="Genre", y="Reviews", data=df2)
plt.show()

# %%
# the average and median number of reviews for fictional books are more than non fictional books
# and so is the std dev

# %%
sns.FacetGrid(df2, hue="Genre", height=5) \
   .map(sns.distplot, "Price") \
   .add_legend()
plt.show()

# %%
print(np.mean(np.array(df2["Price"][df["Genre"]=="Fiction"])))
print(np.median(np.array(df2["Price"][df["Genre"]=="Fiction"])))
print(np.std(np.array(df2["Price"][df["Genre"]=="Fiction"])))
# Out:
# 10.85
# 9.0
# 8.554871906307733

# %%
print(np.mean(np.array(df2["Price"][df["Genre"]=="Non Fiction"])))
print(np.median(np.array(df2["Price"][df["Genre"]=="Non Fiction"])))
print(np.std(np.array(df2["Price"][df["Genre"]=="Non Fiction"])))
# Out:
# 14.841935483870968
# 12.0
# 12.023800971501867

# %%
sns.boxplot(x="Genre", y="Price", data=df2)
plt.show()

# %%
# most of the popular fictional books are lowered priced than non fictinal books
